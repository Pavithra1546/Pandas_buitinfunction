# %%
import pandas as pd 
dataset=pd.read_csv("Hit or Flop movie Dataset.csv")
dataset
# Out:
#     S.No Film Industry                      Movie Name      Genre  \
# 0      1     Kollywood                          Vikram     Action
# 1      2     Kollywood                          Sardar     Action
# 2      3     Kollywood                           Beast     Action
# 3      4     Kollywood                           Pizza     Horror
# 4      5     Kollywood  Naduvula Konjum Pakkatha kanum     Comedy
# 5      6     Kollywood                            Don      Comedy
# 6      7     Kollywood                          Doctor     Action
# 7      8     Kollywood               Ponniyin selvan-1     Action
# 8      9     Kollywood                        Maanaadu     Action
# 9     10     Kollywood                          Master     Action
# 10    11     Kollywood                 Soorarai pottru      Drama
# 11    12     Kollywood         Theeran Adhigaram ondru     Action
# 12    13     Kollywood               Ka Pae Ranasingam      Drama
# ...

# %% [markdown]
# # Selecting a series/column in a dataframe
# There are two ways you can select a column of a dataframe.
#
# data.Name
# data['Name']

# %%
dataset["Movie Name"]
# Out:
# 0                             Vikram
# 1                             Sardar
# 2                              Beast
# 3                              Pizza
# 4     Naduvula Konjum Pakkatha kanum
# 5                               Don
# 6                             Doctor
# 7                  Ponniyin selvan-1
# 8                           Maanaadu
# 9                             Master
# 10                   Soorarai pottru
# 11           Theeran Adhigaram ondru
# 12                 Ka Pae Ranasingam
# 13                            Karnan
# 14                            Asuran
# 15                                 2
# 16                                24
# 17                  English vinglish
# 18                       Viswaroopam
# 19                           Kaththi
# 20                          Mahanati
# 21           Baahubali-The beginning
# 22                          Enthiran
# 23                      Kakka muttai
# 24                          Jai Bhim
# ...

# %% [markdown]
# # we got an error

# %%
dataset.Movie Name
# Out:
#   File "C:\Users\spavi\AppData\Local\Temp\ipykernel_13956\375034284.py", line 1
#     dataset.Movie Name
#                      ^
# SyntaxError: invalid syntax

# %%
dataset.rename(columns={"Movie Name":"MovieName"},inplace=True)
dataset.head()
# Out:
#    S.No Film Industry                       MovieName   Genre  \
# 0     1     Kollywood                          Vikram  Action
# 1     2     Kollywood                          Sardar  Action
# 2     3     Kollywood                           Beast  Action
# 3     4     Kollywood                           Pizza  Horror
# 4     5     Kollywood  Naduvula Konjum Pakkatha kanum  Comedy
#
#   Movie Release Date Investment  Investment.1     Profit    Profit.1  \
# 0           3/6/2022  115 Crore    1150000000  424 Crore  4240000000
# 1         21-10-2022   40 Crore     400000000   85 Crore   850000000
# 2         13-04-2022  130 Crore    1300000000  227 Crore  2270000000
# 3         19-10-2012  1.5 Crore      15000000    8 Crore    80000000
# 4         30-11-2012  0.8 Crore       8000000   18 Crore   180000000
#
#    Success/Failure  ...  Pre-released_song _views first song released date  \
# 0                1  ...                  98000000               15-05-2022
# ...

# %% [markdown]
# # Now there is no error
# you can see the difference

# %%
dataset.MovieName
# Out:
# 0                             Vikram
# 1                             Sardar
# 2                              Beast
# 3                              Pizza
# 4     Naduvula Konjum Pakkatha kanum
# 5                               Don
# 6                             Doctor
# 7                  Ponniyin selvan-1
# 8                           Maanaadu
# 9                             Master
# 10                   Soorarai pottru
# 11           Theeran Adhigaram ondru
# 12                 Ka Pae Ranasingam
# 13                            Karnan
# 14                            Asuran
# 15                                 2
# 16                                24
# 17                  English vinglish
# 18                       Viswaroopam
# 19                           Kaththi
# 20                          Mahanati
# 21           Baahubali-The beginning
# 22                          Enthiran
# 23                      Kakka muttai
# 24                          Jai Bhim
# ...

# %% [markdown]
# # Index Based Selection
# We use iloc to select data based on their numerical position in the dataframe.
#
# iloc takes two argument, first is row followed by column. It has a starting index of 0 that is 0 is first, 1 is second, 2 is third and so on.

# %% [markdown]
# # First row and all columns

# %%
dataset.iloc[0, :]
# Out:
# S.No                                             1
# Film Industry                            Kollywood
# MovieName                                   Vikram
# Genre                                       Action
# Movie Release Date                        3/6/2022
# Investment                               115 Crore
# Investment.1                            1150000000
# Profit                                   424 Crore
# Profit.1                                4240000000
# Success/Failure                                  1
# IMDb Rating                                    8.4
# Trailer Released Date                   15-05-2022
# YouTube_Views1                          43 Million
# YouTube_Trailer_Views                     43000000
# Common Background music                          1
# Theme background Music                           0
# No.of Part Released                              5
# Comedy Scene                                     1
# ...

# %% [markdown]
# # third column that is the MovieName column and all rows
# # Since starting index is 0 third column corresponds to index number 2

# %%
dataset.iloc[: ,2]
# Out:
# 0                             Vikram
# 1                             Sardar
# 2                              Beast
# 3                              Pizza
# 4     Naduvula Konjum Pakkatha kanum
# 5                               Don
# 6                             Doctor
# 7                  Ponniyin selvan-1
# 8                           Maanaadu
# 9                             Master
# 10                   Soorarai pottru
# 11           Theeran Adhigaram ondru
# 12                 Ka Pae Ranasingam
# 13                            Karnan
# 14                            Asuran
# 15                                 2
# 16                                24
# 17                  English vinglish
# 18                       Viswaroopam
# 19                           Kaththi
# 20                          Mahanati
# 21           Baahubali-The beginning
# 22                          Enthiran
# 23                      Kakka muttai
# 24                          Jai Bhim
# ...

# %% [markdown]
# # Suppose we want to select a range of values.
#
# #iloc includes the first number but exclude the last number of the range. For example, if we want the second and third row of the first column, the code is as follows:

# %% [markdown]
# # third and fourth rows of the fourth column

# %%
dataset.iloc[3:5,3]
# Out:
#     Genre Movie Release Date
# 3  Horror         19-10-2012
# 4  Comedy         30-11-2012

# %% [markdown]
# # display the third and fourth rows and third and fourth columns

# %%
dataset.iloc[3:5,3:5]
# Out:
#     Genre Movie Release Date
# 3  Horror         19-10-2012
# 4  Comedy         30-11-2012

# %% [markdown]
# # display the first 2 rows and first 5 columns

# %%
dataset.iloc[:2,:5]
# Out:
#    S.No Film Industry MovieName   Genre Movie Release Date
# 0     1     Kollywood    Vikram  Action           3/6/2022
# 1     2     Kollywood    Sardar  Action         21-10-2022

# %% [markdown]
# # First three rows and all columns

# %%
dataset.iloc[[0,1,2], :]
# Out:
#    S.No Film Industry MovieName   Genre Movie Release Date Investment  \
# 0     1     Kollywood    Vikram  Action           3/6/2022  115 Crore
# 1     2     Kollywood    Sardar  Action         21-10-2022   40 Crore
# 2     3     Kollywood     Beast  Action         13-04-2022  130 Crore
#
#    Investment.1     Profit    Profit.1  Success/Failure  ...  \
# 0    1150000000  424 Crore  4240000000                1  ...
# 1     400000000   85 Crore   850000000                1  ...
# 2    1300000000  227 Crore  2270000000                1  ...
#
#    Pre-released_song _views first song released date YouTube Views  \
# 0                  98000000               15-05-2022    50 Million
# 1                   4000000               18-11-2022    11 Million
# 2                  33000000               14-02-2022    48 Million
#
#    YouTube_song_Views       OTT  Rating_Type  MemeMarketing  Critics  \
# 0            50000000  Netflix          Good            Yes     Good
# ...

# %% [markdown]
# # Bottom five rows of the dataframe

# %%
dataset.iloc[-5: , :]
# Out:
#     S.No Film Industry      MovieName   Genre Movie Release Date Investment  \
# 45    46     Kollywood          Cobra  Action         31-08-2022   90 Crore
# 46    47     Kollywood      Mappillai  Action           8/4/2011   33 Crore
# 47    48     Kollywood  Uttama villan  Comedy           2/5/2015   50 Crore
# 48    49     Kollywood    Kochadaiyan  Action         23-05-2014  125 Crore
# 49    50     Kollywood         Anjaan  Action         15-08-2014   75 Crore
#
#     Investment.1    Profit   Profit.1  Success/Failure  ...  \
# 45     900000000  58 Crore  580000000                0  ...
# 46     330000000  32 Crore  320000000                0  ...
# 47     500000000  26 Crore  260000000                0  ...
# 48    1250000000  42 Crore  420000000                0  ...
# 49     750000000  45 Crore  450000000                0  ...
#
#     Pre-released_song _views first song released date YouTube Views  \
# 45                   6200000                 9/8/2022    29 Million
# ...
