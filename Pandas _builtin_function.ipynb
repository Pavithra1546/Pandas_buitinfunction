# %% [markdown]
# # Pandas Buitin function
# 1)loc[]
#   DataFrame.loc[] method is used to retrieve rows from Pandas DataFrame

# %%
import pandas as pd
data = pd.read_csv("Hit or Flop movie Dataset.csv",index_col ="Movie Name")
data.loc["Sardar"]
# Out:
# S.No                                             2
# Film Industry                            Kollywood
# Genre                                       Action
# Movie Release Date                      21-10-2022
# Investment                                40 Crore
# Investment.1                             400000000
# Profit                                    85 Crore
# Profit.1                                 850000000
# Success/Failure                                  1
# IMDb Rating                                    7.8
# Trailer Released Date                   30-09-2022
# YouTube_Views1                          10 Million
# YouTube_Trailer_Views                     10000000
# Common Background music                          0
# Theme background Music                           1
# No.of Part Released                              4
# Comedy Scene                                     1
# Fast mode                                        1
# ...

# %% [markdown]
# # 2)iloc[]
# Rows can also be selected by passing integer location to an iloc[] function.

# %%
data.iloc[3:5]
# Out:
#                                 S.No Film Industry   Genre Movie Release Date  \
# Movie Name
# Pizza                              4     Kollywood  Horror         19-10-2012
# Naduvula Konjum Pakkatha kanum     5     Kollywood  Comedy         30-11-2012
#
#                                Investment  Investment.1    Profit   Profit.1  \
# Movie Name
# Pizza                           1.5 Crore      15000000   8 Crore   80000000
# Naduvula Konjum Pakkatha kanum  0.8 Crore       8000000  18 Crore  180000000
#
#                                 Success/Failure  IMDb Rating  ...  \
# Movie Name                                                    ...
# Pizza                                         1          8.0  ...
# Naduvula Konjum Pakkatha kanum                1          8.2  ...
#
#                                Pre-released_song _views  \
# Movie Name
# Pizza                                            176000
# Naduvula Konjum Pakkatha kanum                    49000
#
# ...

# %% [markdown]
# # 3)head()
# head(n) is used to return the first n rows of a dataset

# %%
data.head(5)
# Out:
#                                 S.No Film Industry   Genre Movie Release Date  \
# Movie Name
# Vikram                             1     Kollywood  Action           3/6/2022
# Sardar                             2     Kollywood  Action         21-10-2022
# Beast                              3     Kollywood  Action         13-04-2022
# Pizza                              4     Kollywood  Horror         19-10-2012
# Naduvula Konjum Pakkatha kanum     5     Kollywood  Comedy         30-11-2012
#
#                                Investment  Investment.1     Profit  \
# Movie Name
# Vikram                          115 Crore    1150000000  424 Crore
# Sardar                           40 Crore     400000000   85 Crore
# Beast                           130 Crore    1300000000  227 Crore
# Pizza                           1.5 Crore      15000000    8 Crore
# Naduvula Konjum Pakkatha kanum  0.8 Crore       8000000   18 Crore
#
# ...

# %% [markdown]
# # 4. memory_usage()
# memory_usage() returns a Pandas Series having the memory usage of each column (in bytes) in a Pandas DataFrame. By specifying the deep attribute as True, we can get to know the actual space being taken by each column.

# %%
data.memory_usage(deep=True)
# Out:
# Index                                5402
# S.No                                  400
# Film Industry                        3300
# Genre                                3149
# Movie Release Date                   3322
# Investment                           3260
# Investment.1                          400
# Profit                               3266
# Profit.1                              400
# Success/Failure                       400
# IMDb Rating                           400
# Trailer Released Date                3319
# YouTube_Views1                       3384
# YouTube_Trailer_Views                 400
# Common Background music               400
# Theme background Music                400
# No.of Part Released                   400
# Comedy Scene                          400
# Fast mode                             400
# Slow mode                             400
# Medium mode                           400
# 1st-30min                            3206
# ...

# %% [markdown]
# # 5. to_datetime()
# to_datetime() converts a Python object to datetime format. It can take an integer, floating point number, list, Pandas Series, or Pandas DataFrame as argument. to_datetime() is very powerful when the dataset has time series values or dates.

# %%
pd.to_datetime(data['Movie Release Date'])
# Out:
# C:\Users\spavi\AppData\Local\Temp\ipykernel_10968\463112674.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.to_datetime(data['Movie Release Date'])
# Movie Name
# Vikram                           2022-03-06
# Sardar                           2022-10-21
# Beast                            2022-04-13
# Pizza                            2012-10-19
# Naduvula Konjum Pakkatha kanum   2012-11-30
# Don                              2022-05-13
# Doctor                           2021-09-10
# Ponniyin selvan-1                2022-09-30
# Maanaadu                         2021-11-25
# Master                           2021-01-13
# Soorarai pottru                  2020-12-11
# Theeran Adhigaram ondru          2017-11-17
# Ka Pae Ranasingam                2020-02-10
# Karnan                           2021-09-04
# ...

# %% [markdown]
# # 6) value_counts()
# value_counts() returns a Pandas Series containing the counts of unique values.

# %%
data['Genre'].value_counts()
# Out:
# Action       36
# Comedy        8
# Drama         4
# Horror        1
# Superhero     1
# Name: Genre, dtype: int64

# %% [markdown]
# # 7) groupby()
# groupby() is used to group a Pandas DataFrame by 1 or more columns, and perform some mathematical operation on it.

# %%
data.groupby(by='Movie Name').YouTube_Trailer_Views.mean()
# Out:
# Movie Name
# 2                                 23000000.0
# 24                                 6800000.0
# Aayirathil Oruvan                   213000.0
# Action                             9400000.0
# Adhavan                              86000.0
# Alex pandian                        780000.0
# Anjaan                             5200000.0
# Asal                                 68000.0
# Asuran                            14000000.0
# Baahubali-The beginning            5300000.0
# Beast                             59000000.0
# Bhoomi                             4200000.0
# Cobra                             26000000.0
# Dev                                4600000.0
# Doctor                            14000000.0
# Don                               14000000.0
# English vinglish                    997000.0
# Enthiran                            414000.0
# Hero                               8400000.0
# Jai Bhim                          24000000.0
# Ka Pae Ranasingam                 45000000.0
# ...

# %% [markdown]
# # 8) sort_values()
# sort_values() is used to sort column in a Pandas DataFrame (or a Pandas Series) by values in ascending or descending order.

# %%
data.sort_values(by='Movie Name', inplace=True)
data
# Out:
#                                 S.No Film Industry      Genre  \
# Movie Name
# 2                                 16     Kollywood     Action
# 24                                17     Kollywood     Action
# Aayirathil Oruvan                 26     Kollywood     Action
# Action                            44     Kollywood     Action
# Adhavan                           35     Kollywood     Action
# Alex pandian                      36     Kollywood     Action
# Anjaan                            50     Kollywood     Action
# Asal                              40     Kollywood     Action
# Asuran                            15     Kollywood     Action
# Baahubali-The beginning           22     Kollywood     Action
# Beast                              3     Kollywood     Action
# Bhoomi                            28     Kollywood     Action
# Cobra                             46     Kollywood     Action
# Dev                               33     Kollywood     Action
# ...

# %% [markdown]
# # 9)shape
# no of rows and columns present in the dataset

# %%
data.shape
# Out:
# (50, 36)

# %% [markdown]
# # 10)info
# Get information on Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 2 to Viswaroopam
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S.No                               50 non-null     int64
#  1   Film Industry                      50 non-null     object
#  2   Genre                              50 non-null     object
#  3   Movie Release Date                 50 non-null     object
#  4   Investment                         50 non-null     object
#  5   Investment.1                       50 non-null     int64
#  6   Profit                             50 non-null     object
#  7   Profit.1                           50 non-null     int64
#  8   Success/Failure                    50 non-null     int64
#  9   IMDb Rating                        50 non-null     float64
#  10  Trailer Released Date              50 non-null     object
# ...
