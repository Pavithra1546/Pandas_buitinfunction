# %%
import pandas as pd 
dataset=pd.read_csv("Hit or Flop movie Dataset.csv")

# %% [markdown]
# # 'head' shows the first five rows of the dataframe by default but you can specify the number of rows in the parenthesis

# %%
dataset.head()
# Out:
#    S.No Film Industry                      Movie Name   Genre  \
# 0     1     Kollywood                          Vikram  Action
# 1     2     Kollywood                          Sardar  Action
# 2     3     Kollywood                           Beast  Action
# 3     4     Kollywood                           Pizza  Horror
# 4     5     Kollywood  Naduvula Konjum Pakkatha kanum  Comedy
#
#   Movie Release Date Investment  Investment.1     Profit    Profit.1  \
# 0           3/6/2022  115 Crore    1150000000  424 Crore  4240000000
# 1         21-10-2022   40 Crore     400000000   85 Crore   850000000
# 2         13-04-2022  130 Crore    1300000000  227 Crore  2270000000
# 3         19-10-2012  1.5 Crore      15000000    8 Crore    80000000
# 4         30-11-2012  0.8 Crore       8000000   18 Crore   180000000
#
#    Success/Failure  ...  Pre-released_song _views first song released date  \
# 0                1  ...                  98000000               15-05-2022
# 1                1  ...                   4000000               18-11-2022
# 2                1  ...                  33000000               14-02-2022
# 3                1  ...                    176000                 6/9/2012
# 4                1  ...                     49000               27-06-2012
#
#   YouTube Views  YouTube_song_Views       OTT  Rating_Type  MemeMarketing  \
# 0    50 Million            50000000  Netflix          Good            Yes
# 1    11 Million            11000000  Netflix          Good            Yes
# 2    48 Million            48000000  Netflix       Average            Yes
# 3  250 Thousand              250000   Netflix         Good             No
# 4   30 Thousand               30000   Netflix         Good             No
#
#    Critics  First day Box office collection  First day Box office collection.1
# 0     Good                         33 Crore                          330000000
# 1     Good                        3.7 Crore                           37000000
# 2  Average                         40 Crore                          400000000
# 3     Good                        1.5 Crore                           15000000
# 4     Good                          5 Crore                           50000000
#
# [5 rows x 37 columns]

# %%
dataset.head(10)
# Out:
#    S.No Film Industry                      Movie Name   Genre  \
# 0     1     Kollywood                          Vikram  Action
# 1     2     Kollywood                          Sardar  Action
# 2     3     Kollywood                           Beast  Action
# 3     4     Kollywood                           Pizza  Horror
# 4     5     Kollywood  Naduvula Konjum Pakkatha kanum  Comedy
# 5     6     Kollywood                            Don   Comedy
# 6     7     Kollywood                          Doctor  Action
# 7     8     Kollywood               Ponniyin selvan-1  Action
# 8     9     Kollywood                        Maanaadu  Action
# 9    10     Kollywood                          Master  Action
#
#   Movie Release Date Investment  Investment.1     Profit    Profit.1  \
# 0           3/6/2022  115 Crore    1150000000  424 Crore  4240000000
# 1         21-10-2022   40 Crore     400000000   85 Crore   850000000
# 2         13-04-2022  130 Crore    1300000000  227 Crore  2270000000
# 3         19-10-2012  1.5 Crore      15000000    8 Crore    80000000
# 4         30-11-2012  0.8 Crore       8000000   18 Crore   180000000
# 5         13-05-2022   40 Crore     400000000  121 Crore  1210000000
# 6          9/10/2021   40 Crore     400000000  101 Crore  1010000000
# 7         30-09-2022  500 Crore    5000000000  495 Crore  4950000000
# 8         25-11-2021   30 Crore     300000000   84 Crore   840000000
# 9         13-01-2021  135 Crore    1350000000  300 Crore  3000000000
#
#    Success/Failure  ...  Pre-released_song _views first song released date  \
# 0                1  ...                  98000000               15-05-2022
# 1                1  ...                   4000000               18-11-2022
# 2                1  ...                  33000000               14-02-2022
# 3                1  ...                    176000                 6/9/2012
# 4                1  ...                     49000               27-06-2012
# 5                1  ...                  98000000               16-12-2021
# 6                1  ...                  34000000                2/10/2021
# 7                1  ...                  62000000               31-07-2022
# 8                1  ...                  38000000               21-06-2021
# 9                1  ...                 112000000               15-03-2020
#
#   YouTube Views  YouTube_song_Views       OTT  Rating_Type  MemeMarketing  \
# 0    50 Million            50000000  Netflix          Good            Yes
# 1    11 Million            11000000  Netflix          Good            Yes
# 2    48 Million            48000000  Netflix       Average            Yes
# 3  250 Thousand              250000   Netflix         Good             No
# 4   30 Thousand               30000   Netflix         Good             No
# 5    47 Million            47000000   Netflix         Good            Yes
# 6    41 Million            41000000   Netflix         Good            Yes
# 7    50 Million            50000000   Netflix    Very good            Yes
# 8    18 Million            18000000   Netflix         Good            Yes
# 9   406 Million           406000000   Netflix         Good            Yes
#
#      Critics  First day Box office collection  \
# 0       Good                         33 Crore
# 1       Good                        3.7 Crore
# 2    Average                         40 Crore
# 3       Good                        1.5 Crore
# 4       Good                          5 Crore
# 5       Good                         15 Crore
# 6       Good                          8 Crore
# 7  Very Good                         34 Crore
# 8       Good                          8 Crore
# 9       Good                         18 Crore
#
#    First day Box office collection.1
# 0                          330000000
# 1                           37000000
# 2                          400000000
# 3                           15000000
# 4                           50000000
# 5                          150000000
# 6                           80000000
# 7                          340000000
# 8                           80000000
# 9                          180000000
#
# [10 rows x 37 columns]

# %% [markdown]
# # 'tail' shows the bottom five rows by default

# %%
dataset.tail()
# Out:
#     S.No Film Industry     Movie Name   Genre Movie Release Date Investment  \
# 45    46     Kollywood          Cobra  Action         31-08-2022   90 Crore
# 46    47     Kollywood      Mappillai  Action           8/4/2011   33 Crore
# 47    48     Kollywood  Uttama villan  Comedy           2/5/2015   50 Crore
# 48    49     Kollywood    Kochadaiyan  Action         23-05-2014  125 Crore
# 49    50     Kollywood         Anjaan  Action         15-08-2014   75 Crore
#
#     Investment.1    Profit   Profit.1  Success/Failure  ...  \
# 45     900000000  58 Crore  580000000                0  ...
# 46     330000000  32 Crore  320000000                0  ...
# 47     500000000  26 Crore  260000000                0  ...
# 48    1250000000  42 Crore  420000000                0  ...
# 49     750000000  45 Crore  450000000                0  ...
#
#     Pre-released_song _views first song released date YouTube Views  \
# 45                   6200000                 9/8/2022    29 Million
# 46                  30000000               30-03-2011   4.4 Million
# 47                    657000                 1/3/2015     2 Million
# 48                   1000000                 9/3/2014    13 Million
# 49                  16000000                10/8/2014    16 Million
#
#     YouTube_song_Views      OTT  Rating_Type  MemeMarketing  Critics  \
# 45            29000000  Netflix          Bad            Yes      Bad
# 46             4400000  Netflix          Bad             No      Bad
# 47             2000000  Netflix          Bad            Yes      Bad
# 48            13000000  Netflix          Bad            Yes      Bad
# 49            16000000  Netflix          Bad            Yes      Bad
#
#     First day Box office collection  First day Box office collection.1
# 45                         24 Crore                          240000000
# 46                          5 Crore                           50000000
# 47                        `10 Crore                          100000000
# 48                          6 Crore                           60000000
# 49                          1 Crore                           10000000
#
# [5 rows x 37 columns]

# %%
dataset.tail(10)
# Out:
#     S.No Film Industry     Movie Name      Genre Movie Release Date  \
# 40    41     Kollywood          Rekka     Action          7/10/2016
# 41    42     Kollywood      Vanamagan     Action         23-06-2017
# 42    43     Kollywood           Hero  Superhero         20-12-2019
# 43    44     Kollywood         Action     Action         15-11-2019
# 44    45     Kollywood        Ravanan     Action         18-06-2010
# 45    46     Kollywood          Cobra     Action         31-08-2022
# 46    47     Kollywood      Mappillai     Action           8/4/2011
# 47    48     Kollywood  Uttama villan     Comedy           2/5/2015
# 48    49     Kollywood    Kochadaiyan     Action         23-05-2014
# 49    50     Kollywood         Anjaan     Action         15-08-2014
#
#    Investment  Investment.1    Profit   Profit.1  Success/Failure  ...  \
# 40   10 Crore     100000000  14 Crore  140000000                0  ...
# 41   18 Crore     180000000  10 Crore  100000000                0  ...
# 42   45 Crore     450000000  40 Crore  400000000                0  ...
# 43   40 Crore     400000000  35 Crore  350000000                0  ...
# 44   55 Crore     550000000  50 Crore  500000000                0  ...
# 45   90 Crore     900000000  58 Crore  580000000                0  ...
# 46   33 Crore     330000000  32 Crore  320000000                0  ...
# 47   50 Crore     500000000  26 Crore  260000000                0  ...
# 48  125 Crore    1250000000  42 Crore  420000000                0  ...
# 49   75 Crore     750000000  45 Crore  450000000                0  ...
#
#     Pre-released_song _views first song released date YouTube Views  \
# 40                   2000000               30-09-2016     7 Million
# 41                   2000000               22-04-2017    12 Million
# 42                   2800000               29-11-2019    30 Million
# 43                   4200000                9/11/2019   5.4 Million
# 44                   2000000                 7/5/2010    38 Million
# 45                   6200000                 9/8/2022    29 Million
# 46                  30000000               30-03-2011   4.4 Million
# 47                    657000                 1/3/2015     2 Million
# 48                   1000000                 9/3/2014    13 Million
# 49                  16000000                10/8/2014    16 Million
#
#     YouTube_song_Views      OTT  Rating_Type  MemeMarketing  Critics  \
# 40             7000000  Netflix          Bad            Yes      Bad
# 41            12000000  Netflix          Bad            Yes      Bad
# 42            30000000  Netflix          Bad            Yes      Bad
# 43             5400000  Netflix          Bad            Yes      Bad
# 44            38000000  Netflix          Bad            Yes      Bad
# 45            29000000  Netflix          Bad            Yes      Bad
# 46             4400000  Netflix          Bad             No      Bad
# 47             2000000  Netflix          Bad            Yes      Bad
# 48            13000000  Netflix          Bad            Yes      Bad
# 49            16000000  Netflix          Bad            Yes      Bad
#
#     First day Box office collection  First day Box office collection.1
# 40                          6 Crore                           60000000
# 41                          2 Crore                           20000000
# 42                       1.31 Crore                           13100000
# 43                          1 Crore                           10000000
# 44                          6 Crore                           60000000
# 45                         24 Crore                          240000000
# 46                          5 Crore                           50000000
# 47                        `10 Crore                          100000000
# 48                          6 Crore                           60000000
# 49                          1 Crore                           10000000
#
# [10 rows x 37 columns]

# %% [markdown]
# # Creating your own dataframe

# %%
data=pd.DataFrame({"Reg No":[4036,4037,4038,4039],'Nanoscience':[95,80,88,93],"Ethics":[88,97,89,76]})
data
# Out:
#    Reg No  Nanoscience  Ethics
# 0    4036           95      88
# 1    4037           80      97
# 2    4038           88      89
# 3    4039           93      76

# %%
import pandas as pd
survey = pd.DataFrame({'James': ['I liked it', 'It could use a bit more salt'], 'Emily': ['It is too sweet', 'Yum!']})
survey
# Out:
#                           James            Emily
# 0                    I liked it  It is too sweet
# 1  It could use a bit more salt             Yum!

# %% [markdown]
# # we can specify an index column when creating a dataframe via the 'index' argument.

# %%
survey = pd.DataFrame({'James': ['I liked it', 'It could use a bit more salt'], 'Emily': ['It is too sweet', 'Yum!']},
                     index = ['Product A', 'Product B'])
survey
# Out:
#                                   James            Emily
# Product A                    I liked it  It is too sweet
# Product B  It could use a bit more salt             Yum!

# %% [markdown]
# # Reset index
# # Try playing around with 'drop' and 'inplace' and see what they do

# %%
survey.reset_index(drop = True,inplace=True)
survey
# Out:
#                           James            Emily
# 0                    I liked it  It is too sweet
# 1  It could use a bit more salt             Yum!

# %% [markdown]
# # Renaming columns

# %%
data.rename(columns={"Nanoscience":"Science","Ethics":"Professional Ethics"},inplace=True)
data
# Out:
#    Reg No  Science  Professional Ethics
# 0    4036       95                   88
# 1    4037       80                   97
# 2    4038       88                   89
# 3    4039       93                   76

# %%
data = data.set_index('Reg No')
data
# Out:
#         Science  Professional Ethics
# Reg No
# 4036         95                   88
# 4037         80                   97
# 4038         88                   89
# 4039         93                   76

# %% [markdown]
# # Dropping columns and rows
# There are a few of ways you can drop columns or rows from your dataframe. In this example, I am only focusing on the 'drop' function.

# %%
data.drop(columns="Science")
# Out:
#         Professional Ethics
# Reg No
# 4036                     88
# 4037                     97
# 4038                     89
# 4039                     76

# %%
data.drop(4039)
# Out:
#         Science  Professional Ethics
# Reg No
# 4036         95                   88
# 4037         80                   97
# 4038         88                   89

# %% [markdown]
# # Create a new column for history subject

# %%
data["History"]=[90,98,87,80]
data
# Out:
#         Science  Professional Ethics  History
# Reg No
# 4036         95                   88       90
# 4037         80                   97       98
# 4038         88                   89       87
# 4039         93                   76       80
